# %%
import librosa
import matplotlib.pyplot as plt
import numpy as np

# %%
with open('C:/Users/денис/Desktop/Project/System-of-calling/data/days.txt', 'r') as f:
    a = list(map(int, f.read().split(', ')))

# %%
audio, sr = librosa.load('C:/Users/денис/Desktop/Project/System-of-calling/sounds/days.mp3', sr=8000)

# %%
plt.figure(figsize=(6, 12))

plt.subplot(2, 1, 1)
librosa.display.waveshow(audio, sr=sr)

plt.subplot(2, 1, 2)
plt.plot([i for i in range(len(a))], a, color="r")
